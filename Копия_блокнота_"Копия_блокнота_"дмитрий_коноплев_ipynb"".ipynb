# %% [markdown]
# <a href="https://colab.research.google.com/github/Dimon-art/Dimon-Art/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%B4%D0%BC%D0%B8%D1%82%D1%80%D0%B8%D0%B9_%D0%BA%D0%BE%D0%BD%D0%BE%D0%BF%D0%BB%D0%B5%D0%B2_ipynb%22%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Новый раздел

# %% [markdown]
# первое занятие

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.102 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 36.5/107.7 GB disk)

# %%
# @title Libraries
# %%capture
# %pip install TerraYolo

import os
import shutil
import random
import gdown
import cv2
import matplotlib.pyplot as plt
from PIL import Image

# %%
# Подключение библиоте
import matplotlib.image as mpimg
import numpy as np

# %%
# %pip install nltk

# %% [markdown]
# > ***подключение гугл диска***

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install matplotlib-venn

# %% [markdown]
# **загрузка модели**

# %%
import os
import zipfile

path = '/content/drive/MyDrive/proplex_1/inclusions_all.zip'

# Use zipfile.ZipFile to access contents of the zip file
with zipfile.ZipFile(path, 'r') as zip_ref:
  # Get a list of all files and directories within the zip file
  print(zip_ref.namelist())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-dd51ea1a1cb3> in <cell line: 7>()
#       5
#       6 # Use zipfile.ZipFile to access contents of the zip file
# ----> 7 with zipfile.ZipFile(path, 'r') as zip_ref:
#       8   # Get a list of all files and directories within the zip file
#       9   print(zip_ref.namelist())
#
# /usr/lib/python3.10/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1252             while True:
#    1253                 try:
# -> 1254                     self.fp = io.open(file, filemode)
#    1255                 except OSError:
#    1256                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/proplex_1/inclusions_all.zip'

# %%
# %pip install gdown

# %%
import gdown

gdown.download('https://colab.research.google.com/drive/1NjKOfNN1Kqxh3PjcBQSKJxqzkAOs7ADz#scrollTo=TvZIRRM7NASS', quiet=False)
# Out:
# Downloading...
# From: https://colab.research.google.com/drive/1NjKOfNN1Kqxh3PjcBQSKJxqzkAOs7ADz#scrollTo=TvZIRRM7NASS
# To: /content/1NjKOfNN1Kqxh3PjcBQSKJxqzkAOs7ADz#scrollTo=TvZIRRM7NASS
# 89.1kB [00:00, 35.7MB/s]
# '1NjKOfNN1Kqxh3PjcBQSKJxqzkAOs7ADz#scrollTo=TvZIRRM7NASS'

# %%
results = model.predict('path/to/image.jpg')

# %%
# Задание имени рабочего каталога
DATASET_DIR = '/content/drive/MyDrive/proplex_1/inclusions_all/dataset'

# %%
import os

# Задание пути к yaml-файлу
DATASET_DIR = '/content/drive/MyDrive/proplex_1/inclusions_all/dataset'
data_path = os.path.join(DATASET_DIR, 'dataset.yaml')

# Список кодировок для проверки
encodings_to_try = ['utf-8', 'ISO-8859-1', 'windows-1252', 'utf-16']

# Попытка открыть файл с разными кодировками
for encoding in encodings_to_try:
    try:
        with open(data_path, 'r', encoding=encoding) as f:
            content = f.read()
            print(f"Содержимое файла с кодировкой {encoding}:\n{content}\n")
        break  # Если успешно прочитали файл, выходим из цикла
    except FileNotFoundError:
        print(f"Файл не найден: {data_path}")
        break  # Прерываем цикл, если файл не найден
    except Exception as e:
        print(f"Произошла ошибка с кодировкой {encoding}: {e}")
# Out:
# Произошла ошибка с кодировкой utf-8: 'utf-8' codec can't decode byte 0xca in position 225: invalid continuation byte
# Содержимое файла с кодировкой ISO-8859-1:
#
# train: C:/Users/febr6/Downloads/Proplex/inclusion/dataset\images/train
# val: C:/Users/febr6/Downloads/Proplex/inclusion/dataset\images/valid
# test: C:/Users/febr6/Downloads/Proplex/inclusion/dataset\images/test
#
# nc: 2  # Êîëè÷åñòâî êëàññîâ
# names: ['class1', 'class2']  # Èìåíà êëàññîâ (çàìåíèòå íà ðåàëüíûå)

# %%
import os

# Задание пути к yaml-файлу
data_path = '/content/drive/MyDrive/proplex_1/inclusions_all/dataset/dataset.yaml'  # Убедитесь, что путь правильный

# Попытка открыть файл с явным указанием кодировки
try:
    with open(data_path, 'r', encoding='utf-8') as f:  # Попробуйте сначала с UTF-8
        print(f.read())
except UnicodeDecodeError:
    # Если возникла ошибка декодирования, попробуйте другую кодировку
    try:
        with open(data_path, 'r', encoding='ISO-8859-1') as f:  # Или используйте другую подходящую кодировку
            print(f.read())
    except Exception as e:
        print(f"Ошибка при чтении файла с кодировкой ISO-8859-1: {e}")
except FileNotFoundError:
    print(f"Файл не найден: {data_path}")
except Exception as e:
    print(f"Произошла ошибка: {e}")
# Out:
# train: C:/Users/febr6/Downloads/Proplex/inclusion/dataset\images/train
# val: C:/Users/febr6/Downloads/Proplex/inclusion/dataset\images/valid
# test: C:/Users/febr6/Downloads/Proplex/inclusion/dataset\images/test
#
# nc: 2  # Êîëè÷åñòâî êëàññîâ
# names: ['class1', 'class2']  # Èìåíà êëàññîâ (çàìåíèòå íà ðåàëüíûå)

# %%
# Путь к корневой директории ваших данных
path = '/content/drive/MyDrive/proplex_1/inclusions_all/dataset'  # Убедитесь, что это путь к директории, а не zip-файл

# Папки с изображениями для обучения и валидации
train_images = os.path.join(path, '/content/drive/MyDrive/proplex_1/inclusions_all/dataset/images/train')  # Путь к папке с обучающими изображениями
val_images = os.path.join(path, '/content/drive/MyDrive/proplex_1/inclusions_all/dataset/labels/valid')      # Путь к папке с валидационными изображениями

# Названия классов
names = {
    0: 'scratch',
    1: 'marker',
    2: 'oil',
    3: 'punctures'
}

# Вывод информации для проверки
print("Путь к обучающим изображениям:", train_images)
print("Путь к валидационным изображениям:", val_images)
print("Названия классов:", names)
# Out:
# Путь к обучающим изображениям: /content/drive/MyDrive/proplex_1/inclusions_all/dataset/images/train
# Путь к валидационным изображениям: /content/drive/MyDrive/proplex_1/inclusions_all/dataset/labels/valid
# Названия классов: {0: 'scratch', 1: 'marker', 2: 'oil', 3: 'punctures'}

# %%
# Пример использования модели для предсказания

from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO("yolov8n.pt")

# Define path to the image file
source = "/content/drive/MyDrive/proplex_1/inclusions_all/dataset/images/valid/04a0707c-frame164.jpg"

# Run inference on the source
results = model(source)  # list of Results objects

# Вывод результатов
for result in results:
    print(f"Изображение: {result.orig_img} - Достижения: {result.names}")
# Out:
# image 1/1 /content/drive/MyDrive/proplex_1/inclusions_all/dataset/images/valid/04a0707c-frame164.jpg: 384x640 (no detections), 8.3ms
# Speed: 3.3ms preprocess, 8.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Изображение: [[[109 118 131]
#   [108 117 130]
#   [108 117 130]
#   ...
#   [ 22  19  21]
#   [ 24  21  23]
#   [ 26  23  25]]
#
#  [[109 118 131]
#   [109 118 131]
#   [109 118 131]
#   ...
#   [ 20  17  19]
#   [ 23  20  22]
#   [ 25  22  24]]
#
#  [[110 119 132]
#   [110 119 132]
#   [110 119 132]
#   ...
#   [ 21  18  20]
#   [ 24  21  23]
#   [ 26  23  25]]
#
#  ...
#
#  [[  8   7  11]
#   [  8   7  11]
#   [  8   7  11]
#   ...
#   [ 26  32  69]
#   [ 27  33  70]
#   [ 28  34  71]]
#
#  [[  5   4   8]
#   [  5   4   8]
#   [  6   5   9]
#   ...
#   [ 26  32  69]
#   [ 27  33  70]
#   [ 28  34  71]]
#
#  [[  3   2   6]
#   [  4   3   7]
#   [  5   4   8]
#   ...
#   [ 28  34  71]
#   [ 29  35  72]
# ...

# %%
# Пример использования модели для предсказания
from ultralytics import YOLO


# Load a pretrained YOLOv8n model
model = YOLO("yolov8n.pt")

# Define path to the image file
source = "/content/drive/MyDrive/proplex_1/inclusions_all/dataset/images/valid/04a0707c-frame164.jpg"

# Run inference on the source
results = model(source)  # list of Results objects

# Вывод результатов
for result in results:
    print(f"Изображение: {result.orig_img} - Достижения: {result.names}")
# Out:
# image 1/1 /content/drive/MyDrive/proplex_1/inclusions_all/dataset/images/valid/04a0707c-frame164.jpg: 384x640 (no detections), 14.9ms
# Speed: 3.3ms preprocess, 14.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Изображение: [[[109 118 131]
#   [108 117 130]
#   [108 117 130]
#   ...
#   [ 22  19  21]
#   [ 24  21  23]
#   [ 26  23  25]]
#
#  [[109 118 131]
#   [109 118 131]
#   [109 118 131]
#   ...
#   [ 20  17  19]
#   [ 23  20  22]
#   [ 25  22  24]]
#
#  [[110 119 132]
#   [110 119 132]
#   [110 119 132]
#   ...
#   [ 21  18  20]
#   [ 24  21  23]
#   [ 26  23  25]]
#
#  ...
#
#  [[  8   7  11]
#   [  8   7  11]
#   [  8   7  11]
#   ...
#   [ 26  32  69]
#   [ 27  33  70]
#   [ 28  34  71]]
#
#  [[  5   4   8]
#   [  5   4   8]
#   [  6   5   9]
#   ...
#   [ 26  32  69]
#   [ 27  33  70]
#   [ 28  34  71]]
#
#  [[  3   2   6]
#   [  4   3   7]
#   [  5   4   8]
#   ...
#   [ 28  34  71]
#   [ 29  35  72]
# ...

# %%
# !yolo predict model=yolov8n.pt source=/content/drive/MyDrive/proplex_1/inclusions_all/dataset/images/test/1d3bfe94-25.jpg
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 92.1MB/s]
# Ultralytics YOLOv8.2.101 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/drive/MyDrive/proplex_1/inclusions_all/dataset/images/test/1d3bfe94-25.jpg: 640x384 (no detections), 40.6ms
# Speed: 3.4ms preprocess, 40.6ms inference, 46.6ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Загрузка модели
model_path = '/content/drive/MyDrive/proplex_1/inclusions_all/yolov8n.pt'  # Убедитесь, что путь правильный
model = YOLO(model_path)

# Выполнение предсказания на тестовом изображении
test_image_path = '/content/drive/MyDrive/proplex_1/inclusions_all/dataset/images/valid/04a0707c-frame164.jpg'
results = model.predict(source=test_image_path)

# %%
import os
import shutil

# Загрузка файла из Google Drive (замените на локальный путь)
archive_path = '/content/drive/MyDrive/proplex_1/inclusions_all.zip'

# Задание имени рабочего каталога
DATASET_DIR = '/content/drive/MyDrive/proplex_1/inclusions_all/dataset'

# Создание рабочего каталога
os.makedirs(DATASET_DIR, exist_ok=True)

# Удаление старых данных (если необходимо)
shutil.rmtree('sample_data', ignore_errors=True)

# Распаковка архива
shutil.unpack_archive(archive_path, DATASET_DIR)
print("Архив успешно разархивирован")

# Удаление архива (если он больше не нужен)
#os.remove(archive_path)
#print("Архив успешно удален")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-813dc4fa9709> in <cell line: 17>()
#      15
#      16 # Распаковка архива
# ---> 17 shutil.unpack_archive(archive_path, DATASET_DIR)
#      18 print("Архив успешно разархивирован")
#      19
#
# /usr/lib/python3.10/shutil.py in unpack_archive(filename, extract_dir, format, filter)
#    1312         func = _UNPACK_FORMATS[format][1]
#    1313         kwargs = dict(_UNPACK_FORMATS[format][2]) | filter_kwargs
# -> 1314         func(filename, extract_dir, **kwargs)
#    1315
#    1316
#
# /usr/lib/python3.10/shutil.py in _unpack_zipfile(filename, extract_dir)
#    1219                 with zip.open(name, 'r') as source, \
#    1220                         open(targetpath, 'wb') as target:
# -> 1221                     copyfileobj(source, target)
#    1222     finally:
#    1223         zip.close()
#
# ...

# %%
from ultralytics import YOLO

# Load a pre-trained model
model = YOLO("yolov8n.pt")

# %%
# Функция для обработки изображения и выполнения предсказания
def predict_image(image_path):
    # Выполнение предсказания
    results = model.predict(image_path)

    # Отображение результатов
    for result in results:
        boxes = result.boxes  # Получаем предсказанные боксы
        for box in boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Координаты бокса
            class_id = int(box.cls)  # Класс объекта
            confidence = box.conf  # Уверенность предсказания
              # Рисуем прямоугольник вокруг обнаруженного объекта
            img = cv2.imread(image_path)
            cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
            label = f"Class: {model.names[class_id]}, Confidence: {confidence:.2f}"
            cv2.putText(img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

    # Отображение изображения с аннотациями
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()

# %%
# Установка необходимых библиотек
# !pip install ultralytics

# Импортирование необходимых библиотек
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Загрузка предобученной модели YOLOv8
model = YOLO("yolov8n.pt")  # Вы можете использовать другие версии, например yolov8s.pt

# Функция для обработки изображения и выполнения предсказания
def predict_image(image_path):
    # Выполнение предсказания
    results = model.predict(image_path)

    # Счетчики для метрик
    true_positives = 0
    false_positives = 0
    false_negatives = 0

    # Чтение изображения для отображения результатов
    img = cv2.imread(image_path)

    # Обработка результатов
    for result in results:
        boxes = result.boxes  # Получаем предсказанные боксы
        for box in boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Координаты бокса
            class_id = int(box.cls)  # Класс объекта
            confidence = box.conf  # Уверенность предсказания

            # Рисуем прямоугольник вокруг обнаруженного объекта
            cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
            label = f"Class: {model.names[class_id]}, Confidence: {confidence:.2f}"
            cv2.putText(img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

            # Условие для подсчета TP/FP/FN (примерная логика)
            if confidence > 0.5:  # Пример: если уверенность больше 0.5 считается TP
                true_positives += 1
            else:
                false_positives += 1

    # Для демонстрации добавим фиксированное значение для ложноотрицательных (можно заменить на реальное)
    false_negatives = max(0, 10 - true_positives)  # Пример: всего ожидается 10 объектов

    # Отображение изображения с аннотациями
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()

    return true_positives, false_positives, false_negatives

# Функция для построения графиков точности и ошибок
def plot_metrics(tp, fp, fn):
    total_predictions = tp + fp + fn

    if total_predictions == 0:
        accuracy = 0
        error_rate = 0
    else:
        accuracy = tp / total_predictions * 100
        error_rate = (fp + fn) / total_predictions * 100

    metrics = ['True Positives', 'False Positives', 'False Negatives']
    values = [tp, fp, fn]

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.bar(metrics, values, color=['green', 'red', 'orange'])
    plt.title('Predictions Count')
    plt.ylabel('Count')

    plt.subplot(1, 2, 2)
    plt.bar(['Accuracy', 'Error Rate'], [accuracy, error_rate], color=['blue', 'purple'])
    plt.title('Model Performance')
    plt.ylabel('Percentage (%)')

    plt.tight_layout()
    plt.show()

# Путь к изображению для обработки (замените на свой путь)
image_path = "/content/drive/MyDrive/proplex_1/inclusions_all/dataset/images/test/179469f5-кадр_0335.png"  # Замените на путь к вашему изображению

# Вызов функции предсказания и получения метрик
true_positives, false_positives, false_negatives = predict_image(image_path)

# Построение графиков точности и ошибок
plot_metrics(true_positives, false_positives, false_negatives)
# Out:
# ...
#
# image 1/1 /content/drive/MyDrive/proplex_1/inclusions_all/dataset/images/test/179469f5-кадр_0335.png: 384x640 (no detections), 151.5ms
# Speed: 4.1ms preprocess, 151.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)

# %%
image_path = "/content/drive/MyDrive/proplex_1/inclusions_all/dataset/images/test/02562471-frame429.jpg"

# %%
import os

image_path = "/content/drive/MyDrive/proplex_1/inclusions_all/dataset/images/test/179469f5-кадр_0335.png"
if not os.path.exists(image_path):
    print(f"Файл не найден: {image_path}")
else:
    print(f"Файл найден: {image_path}")
# Out:
# Файл найден: /content/drive/MyDrive/proplex_1/inclusions_all/dataset/images/test/179469f5-кадр_0335.png

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os

# Загрузка предобученной модели YOLOv8
model = YOLO("yolov8n.pt")  # Убедитесь, что файл yolov8n.pt доступен

# Путь к изображению для обработки (замените на свой путь)
image_path = "/content/drive/MyDrive/proplex_1/inclusions_all/dataset/images/test/179469f5-кадр_0335.png"

# Проверка существования файла
if not os.path.exists(image_path):
    print(f"Файл не найден: {image_path}")
else:
    # Функция для обработки изображения и выполнения предсказания
    def predict_image(image_path):
        # Выполнение предсказания
        results = model.predict(image_path)

        # Счетчики для метрик
        true_positives = 0
        false_positives = 0
        false_negatives = 0

        # Чтение изображения для отображения результатов
        img = cv2.imread(image_path)

        # Обработка результатов
        for result in results:
            boxes = result.boxes  # Получаем предсказанные боксы
            for box in boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])  # Координаты бокса
                class_id = int(box.cls)  # Класс объекта
                confidence = box.conf  # Уверенность предсказания

                # Рисуем прямоугольник вокруг обнаруженного объекта
                cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
                label = f"Class: {model.names[class_id]}, Confidence: {confidence:.2f}"
                cv2.putText(img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

                # Условие для подсчета TP/FP/FN (примерная логика)
                if confidence > 0.5:  # Пример: если уверенность больше 0.5 считается TP
                    true_positives += 1
                else:
                    false_positives += 1

        # Для демонстрации добавим фиксированное значение для ложноотрицательных (можно заменить на реальное)
        false_negatives = max(0, 10 - true_positives)  # Пример: всего ожидается 10 объектов

        # Отображение изображения с аннотациями
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.show()

        return true_positives, false_positives, false_negatives

    # Вызов функции предсказания и получения метрик
    true_positives, false_positives, false_negatives = predict_image(image_path)

    # Функция для построения графиков точности и ошибок
    def plot_metrics(tp, fp, fn):
        total_predictions = tp + fp + fn

        if total_predictions == 0:
            accuracy = 0
            error_rate = 0
        else:
            accuracy = tp / total_predictions * 100
            error_rate = (fp + fn) / total_predictions * 100

        epochs = range(1, len(accuracy) + 1)  # Предполагается, что accuracy и error_rate - списки

        plt.figure(figsize=(12, 6))

        plt.subplot(1, 2, 1)
        plt.plot(epochs, accuracy, label='Accuracy')
        plt.plot(epochs, error_rate, label='Error Rate')
        plt.title('Accuracy and Error Rate')
        plt.xlabel('Epochs')
        plt.ylabel('Percentage (%)')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(epochs, tp, label='True Positives')
        plt.plot(epochs, fp, label='False Positives')
        plt.plot(epochs, fn, label='False Negatives')
        plt.title('Metrics over Epochs')
        plt.xlabel('Epochs')
        plt.ylabel('Count')
        plt.legend()

        plt.tight_layout()
        plt.show()

    # Построение графиков точности и ошибок
   # plot_metrics([true_positives], [false_positives], [false_negatives])
# Out:
# image 1/1 /content/drive/MyDrive/proplex_1/inclusions_all/dataset/images/test/179469f5-кадр_0335.png: 384x640 (no detections), 8.0ms
# Speed: 3.4ms preprocess, 8.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Установка необходимых библиотек
import ultralytics

# Импортирование необходимых библиотек
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Загрузка предобученной модели YOLOv8
model = YOLO("yolov8n.pt")  # Вы можете использовать другие версии, например yolov8s.pt
image_path = "/content/drive/MyDrive/proplex_1/inclusions_all/dataset/images/test/07de3c02-frame373.jpg"

#image_path = "/content/drive/MyDrive/proplex_1/inclusions_all/dataset/images/test/179469f5-кадр_0335.png"
# Функция для обработки изображения и выполнения предсказания
def predict_image(image_path):
    # Выполнение предсказания
    results = model.predict(image_path)

    # Счетчики для метрик
    true_positives = 0
    false_positives = 0
    false_negatives = 0

    # Чтение изображения для отображения результатов
    img = cv2.imread(image_path)

    # Обработка результатов
    for result in results:
        boxes = result.boxes  # Получаем предсказанные боксы
        for box in boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Координаты бокса
            class_id = int(box.cls)  # Класс объекта
            confidence = box.conf  # Уверенность предсказания

            # Рисуем прямоугольник вокруг обнаруженного объекта
            cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
            label = f"Class: {model.names[class_id]}, Confidence: {confidence:.2f}"
            cv2.putText(img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

            # Условие для подсчета TP/FP/FN (примерная логика)
            if confidence > 0.5:  # Пример: если уверенность больше 0.5 считается TP
                true_positives += 1
            else:
                false_positives += 1

    # Для демонстрации добавим фиксированное значение для ложноотрицательных (можно заменить на реальное)
    false_negatives = max(0, 10 - true_positives)  # Пример: всего ожидается 10 объектов

    # Отображение изображения с аннотациями
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()

    return true_positives, false_positives, false_negatives

# Функция для построения графиков точности и ошибок
def plot_metrics(tp, fp, fn):
    total_predictions = tp + fp + fn

    if total_predictions == 0:
        accuracy = 0
        error_rate = 0
    else:
        accuracy = tp / total_predictions * 100
        error_rate = (fp + fn) / total_predictions * 100

    metrics = ['True Positives', 'False Positives', 'False Negatives']
    values = [tp, fp, fn]

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.bar(metrics, values, color=['green', 'red', 'orange'])
    plt.title('Predictions Count')
    plt.ylabel('Count')

    plt.subplot(1, 2, 2)
    plt.bar(['Accuracy', 'Error Rate'], [accuracy, error_rate], color=['blue', 'purple'])
    plt.title('Model Performance')
    plt.ylabel('Percentage (%)')

    plt.tight_layout()
    plt.show()

# Путь к изображению для обработки (замените на свой путь)
image_path = "/content/drive/MyDrive/proplex_1/inclusions_all/dataset/images/test/02562471-frame429.jpg"  # Замените на путь к вашему изображению

# Вызов функции предсказания и получения метрик
#true_positives, false_positives, false_negatives = predict_image(image_path)

# Построение графиков точности и ошибок
plot_metrics(true_positives, false_positives, false_negatives)

# %%
from ultralytics import YOLO
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0bf2fd45f7d1> in <cell line: 1>()
# ----> 1 from ultralytics import YOLO
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.101 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 37.0/107.7 GB disk)

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.101 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 37.0/107.7 GB disk)

# %%
# !pip install -U ultralytics

# %%
import ultralytics
print(ultralytics.__version__)
# Out:
# 8.2.101

# %%
from ultralytics import YOLO
from ultralytics.utils.metrics import ConfusionMatrix  # Correct path for ConfusionMatrix

# %%
import ultralytics
print(dir(ultralytics))
# Out:
# ['ASSETS', 'Explorer', 'FastSAM', 'NAS', 'RTDETR', 'SAM', 'SETTINGS', 'YOLO', 'YOLOWorld', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'cfg', 'checks', 'data', 'download', 'engine', 'hub', 'models', 'nn', 'os', 'settings', 'utils']

# %%
data_path = '/content/drive/MyDrive/proplex_1/inclusions_all/dataset/dataset.yaml'

# %%
DATASET_DIR = '/content/drive/MyDrive/proplex_1/inclusions_all/dataset'

# %%
img_list = sorted(os.listdir('/content/drive/MyDrive/proplex_1/inclusions_all/dataset/labels'))
#lable_list = sorted(os.listdir('/content/dataset/train/labels'))

lable_list = sorted(os.listdir('/content/drive/MyDrive/proplex_1/inclusions_all/dataset/labels'))

print(img_list[0])
print(lable_list[0])
# Out:
# test
# test

# %%
[f'Длина {os.path.join(root,folder)}: {len(os.listdir(os.path.join(root,folder)))}' for root, folders, files, in os.walk('/content/drive/MyDrive/proplex_1/inclusions_all/dataset/dataset') for folder in folders]
# Out:
# ['Длина /content/drive/MyDrive/proplex_1/inclusions_all/dataset/dataset/images: 3',
#  'Длина /content/drive/MyDrive/proplex_1/inclusions_all/dataset/dataset/labels: 3',
#  'Длина /content/drive/MyDrive/proplex_1/inclusions_all/dataset/dataset/images/test: 128',
#  'Длина /content/drive/MyDrive/proplex_1/inclusions_all/dataset/dataset/images/train: 954',
#  'Длина /content/drive/MyDrive/proplex_1/inclusions_all/dataset/dataset/images/valid: 190',
#  'Длина /content/drive/MyDrive/proplex_1/inclusions_all/dataset/dataset/labels/test: 128',
#  'Длина /content/drive/MyDrive/proplex_1/inclusions_all/dataset/dataset/labels/train: 954',
#  'Длина /content/drive/MyDrive/proplex_1/inclusions_all/dataset/dataset/labels/valid: 190']

# %%
#img_list = sorted(os.listdir('/content/dataset/train/images'))

img_list = sorted(os.listdir('/content/drive/MyDrive/proplex_1/inclusions_all/dataset/images'))

lable_list = sorted(os.listdir('/content/drive/MyDrive/proplex_1/inclusions_all/dataset/labels'))

print(img_list[0])
print(lable_list[0])
# Out:
# test
# test

# %%
print(data_path)
print(DATASET_DIR)
# Out:
# /content/drive/MyDrive/proplex_1/inclusions_all/dataset/dataset.yaml
# /content/drive/MyDrive/proplex_1/inclusions_all/dataset

# %%
#my_terra_yolov5 = TerraYoloV5(work_dir=DATASET_DIR)

from ultralytics import YOLO

model = YOLO('yolov8s.pt')  # Load the small version of YOLOv8
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 367MB/s]

# %%
results = model.train(data='path/to/your/data.yaml', epochs=50, imgsz=640)

# %%
results = model.predict('path/to/image.jpg')

# %%
# Вывод числа объектов в датасете
my_terra_yolov5.count_labels(data_path)

# %%
# prompt: # Вывод структуры модели
# my_terra_yolov5.get_annotation('yolov5s')

# Вывод структуры модели
my_terra_yolov5.get_model_structure('yolov5s')

# %%
# Сохраненные веса
# !ls /content/dataset/yolov5/runs/train/exp/weights

# %%
my_terra_yolov5.exp_dict['train']['last_exp_path']+'/weights/best.pt'

# %%
TRAIN_DIR = '/content/dataset'

test_dict = dict()
test_dict['source'] = TRAIN_DIR+'/valid/images/'
test_dict['conf'] = 0.5                                     # порог вероятности обнаружения объекта
test_dict['weights'] = my_terra_yolov5.exp_dict['train']['last_exp_path']+'/weights/best.pt' #путь к весам модели

my_terra_yolov5.run(test_dict, exp_type='test')

# %%
my_terra_yolov5.show_test_images(n_samples=7, img_dir=None) #показать n_samples изображений

# %%
train_dict['weights'] = my_terra_yolov5.exp_dict['train'][
                                            'last_exp_path']+'/weights/last.pt' #веса последней эпохи
train_dict['epochs'] = 5
my_terra_yolov5.run(train_dict, exp_type='train') #запуск скрипта train  с параметрами train_dict

# %%
#путь к лучшим весам модели
test_dict['weights'] = my_terra_yolov5.exp_dict['train'][
                                            'last_exp_path']+'/weights/best.pt'

my_terra_yolov5.run(test_dict, exp_type='test') #запускаем скрипт test с параметрами test_dic

# %%
my_terra_yolov5.show_test_images(n_samples=7)

# %%
test_dict['conf'] = 0.3 #снизим порог
my_terra_yolov5.run(test_dict, exp_type='test')

my_terra_yolov5.show_test_images(n_samples=7)

# %%
val_dict=dict()
val_dict['data'] = train_dict['data']

val_dict['weights'] = os.path.abspath(
        my_terra_yolov5.exp_dict['train']['last_exp_path']+'/weights/last.pt')
my_terra_yolov5.run(val_dict, exp_type='val')

# %%
my_terra_yolov5.show_val_results(img_path=None, img_list=['confusion_matrix.png', 'PR_curve.png'])

# %%
from google.colab import drive # импорт модуля для работы с диском
drive.mount('/content/drive/') # монтируем свой диск в папку drive рабочего каталога

# %%
my_drv_path = '/content/drive/MyDrive/' #сохраним путь к нашему диску в переменную

# %%
# !mkdir {my_drv_path}/yolo_weights/

# %%
# сохраним путь в переменную
best_weights_path = my_terra_yolov5.exp_dict['train']['last_exp_path']+'/weights/best.pt'
# и скопируем веса
# !cp {best_weights_path} {my_drv_path+'/yolo_weights/'}

# %%
# !ls {my_drv_path+'/yolo_weights/'}

# %%
# !pip install ultralytics # install the ultralytics package
import cv2
import numpy as np
from ultralytics import YOLO # import YOLO from ultralytics
import matplotlib.pyplot as plt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 874.1/874.1 kB 12.5 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import gdown

# a file
url = "https://drive.google.com/uc?id=1l_5RK28JRL19wpT22B-DY9We3TVXnnQQ"
output = "fcn8s_from_caffe.npz"
gdown.download(url, output)

# same as the above, but with the file ID
id = "0B9P1L--7Wd2vNm9zMTJWOGxobkU"
gdown.download(id=id, output=output)

# same as the above, and you can copy-and-paste a URL from Google Drive with fuzzy=True
url = "https://drive.google.com/file/d/0B9P1L--7Wd2vNm9zMTJWOGxobkU/view?usp=sharing"
gdown.download(url=url, output=output, fuzzy=True)

# Cached download with identity check via MD5 (or SHA1, SHA256, etc).
# Pass postprocess function e.g., extracting compressed file.
md5 = "md5:fa837a88f0c40c513d975104edf3da17"
gdown.cached_download(url, output, hash=hash, postprocess=gdown.extractall)

# a folder
url = "https://drive.google.com/drive/folders/15uNXeRBIhVvZJIhL4yTw4IsStMhUaaxl"
gdown.download_folder(url)

# same as the above, but with the folder ID
id = "15uNXeRBIhVvZJIhL4yTw4IsStMhUaaxl"

15uNXeRBIhVvZJIhL4yTw4IsStMhUaaxl
gdown.download_folder(id=id)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1l_5RK28JRL19wpT22B-DY9We3TVXnnQQ
# From (redirected): https://drive.google.com/uc?id=1l_5RK28JRL19wpT22B-DY9We3TVXnnQQ&confirm=t&uuid=38968609-d66b-4ba2-89f9-f3146469450c
# To: /content/fcn8s_from_caffe.npz
# 100%|██████████| 499M/499M [00:12<00:00, 39.2MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/download.py:33: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = bs4.BeautifulSoup(line, features="html.parser")
# ---------------------------------------------------------------------------
# FileURLRetrievalError                     Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/gdown/download.py in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume, format, user_agent, log_messages)
#     266         try:
# ...

# %%
# Загрузка предобученной модели YOLOv8
model = YOLO("yolov8n.pt")  # Можно использовать другие версии, например yolov8s.pt

# Функция для обработки изображений дефектов оконного профиля
def process_window_defects(image_path):
    # Чтение изображения
    image = cv2.imread(image_path)

    # Выполнение предсказания
    results = model.predict(image_path)

    # Список для хранения результатов
    true_positives = 0
    false_positives = 0
    false_negatives = 0

    # Обработка результатов
    for result in results:
        boxes = result.boxes  # Получаем предсказанные боксы
        for box in boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Координаты бокса
            class_id = int(box.cls)  # Класс объекта
            confidence = box.conf  # Уверенность предсказания

            # Рисуем прямоугольник вокруг обнаруженного дефекта
            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
            label = f"Class: {model.names[class_id]}, Confidence: {confidence:.2f}"
            cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

            # Здесь можно добавить логику для подсчета TP/FP/FN
            if confidence > 0.5:  # Пример: если уверенность больше 0.5 считается TP
                true_positives += 1
            else:
                false_positives += 1

    # Для демонстрации добавим фиксированное значение для ложноотрицательных (можно заменить на реальное)
    false_negatives = max(0, 10 - true_positives)  # Пример: всего ожидается 10 объектов

    # Отображение результата
    cv2.imshow("Detected Defects", image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    return true_positives, false_positives, false_negatives

# Функция для построения графиков точности и ошибок
def plot_metrics(tp, fp, fn):
    total_predictions = tp + fp + fn

    if total_predictions == 0:
        accuracy = 0
        error_rate = 0
    else:
        accuracy = tp / total_predictions * 100
        error_rate = (fp + fn) / total_predictions * 100

    metrics = ['True Positives', 'False Positives', 'False Negatives']
    values = [tp, fp, fn]

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.bar(metrics, values, color=['green', 'red', 'orange'])
    plt.title('Predictions Count')
    plt.ylabel('Count')

    plt.subplot(1, 2, 2)
    plt.bar(['Accuracy', 'Error Rate'], [accuracy, error_rate], color=['blue', 'purple'])
    plt.title('Model Performance')
    plt.ylabel('Percentage (%)')

    plt.tight_layout()
    plt.show()

# Путь к изображению для обработки
image_path = "path/to/your/window_defect_image.jpg"  # Замените на путь к вашему изображению

# Вызов функции обработки изображений и получения метрик
true_positives, false_positives, false_negatives = process_window_defects(image_path)

# Построение графиков точности и ошибок
plot_metrics(true_positives, false_positives, false_negatives)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3deb8205b133> in <cell line: 2>()
#       1 # Загрузка предобученной модели YOLOv8
# ----> 2 model = YOLO("yolov8n.pt")  # Можно использовать другие версии, например yolov8s.pt
#       3
#       4 # Функция для обработки изображений дефектов оконного профиля
#       5 def process_window_defects(image_path):
#
# NameError: name 'YOLO' is not defined

# %%
# Установка необходимых пакетов
# !pip install ultralytics
# !pip install gdown
# !pip install nltk
# !pip install matplotlib
#

# to upgrade
#
import os
import shutil
import gdown
import cv2
import matplotlib.pyplot as plt
import yaml
from ultralytics import YOLO

# Загрузка данных с Google Диска
url = '/content/drive/MyDrive/proplex_1/inclusions_all/dataset'  # Замените FILE_ID на идентификатор файла на Google Диске
output = '/content/drive/MyDrive/proplex_1/inclusions_all/dataset'
gdown.download(url, output, quiet=False)

# Распаковка архива
shutil.unpack_archive(output, '/content/drive/MyDrive/proplex_1/inclusions_all/dataset')
os.remove(output)

# Создание рабочего каталога и перемещение распакованных данных в него
DATASET_DIR = '/content/dataset'
os.makedirs(DATASET_DIR, exist_ok=True)

# Получаем количество классов и пути к изображениям и меткам
num_classes = len(os.listdir(os.path.join(DATASET_DIR, 'train', 'labels')))
image_paths = [os.path.join(DATASET_DIR, 'train', 'images', img) for img in os.listdir(os.path.join(DATASET_DIR, 'train', 'images'))]
label_paths = [os.path.join(DATASET_DIR, 'train', 'labels', lbl) for lbl in os.listdir(os.path.join(DATASET_DIR, 'train', 'labels'))]

# Создаем словарь с информацией о датасете
data_dict = {
    'train': {
        'images': image_paths,
        'labels': label_paths,
        'nc': num_classes
    }
}

# Сохраняем словарь в yaml-файл
with open(os.path.join(DATASET_DIR, 'data.yaml'), 'w') as f:
    yaml.safe_dump(data_dict, f)

# Инициализируем объект YOLOv8
model = YOLO('yolov8n.pt')  # Замените на yolov8n.pt или другую модель по вашему выбору

# Задаем параметры обучения
train_dict = {
    'epochs': 100,  # Количество эпох
    'batch_size': 16,  # Размер мини-батча
    'img_size': 640,  # Размер кадра
    'learning_rate': 0.0001,  # Скорость обучения
    'device': '0'  # Устройство для обучения (например, '0' для использования GPU 0)
}

# Запускаем обучение модели с заданными параметрами
results = model.train(data=os.path.join(DATASET_DIR, 'data.yaml'), epochs=train_dict['epochs'], imgsz=train_dict['img_size'], batch=train_dict['batch_size'], lr0=train_dict['learning_rate'])

# Построение графиков результатов обучения
def plot_results(results):
    plt.figure(figsize=(12, 6))

    # График mAP (mean Average Precision)
    plt.subplot(1, 2, 1)
    plt.plot(results['metrics']['mAP_0.5'], label='mAP@0.5')
    plt.plot(results['metrics']['mAP_0.5:0.95'], label='mAP@0.5:0.95')
    plt.title('Mean Average Precision')
    plt.xlabel('Epochs')
    plt.ylabel('mAP')
    plt.legend()

    # График потерь (loss)
    plt.subplot(1, 2, 2)
    plt.plot(results['metrics']['loss'], label='Loss')
    plt.title('Training Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_results(results)

# Загружаем модель после обучения для предсказаний
model.load('best.pt')  # Замените на путь к файлу с лучшей моделью после обучения

# Делаем предсказание на кадре
image_path = os.path.join(DATASET_DIR, 'val', 'images', '000001.jpg')  # Укажите путь к кадру для предсказания
image = cv2.imread(image_path)
predictions = model.predict(image)

# Отображаем кадр с предсказаниями
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title('Predictions')
plt.show()
# Out:
# ...
# ---------------------------------------------------------------------------
# FileURLRetrievalError                     Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/gdown/download.py in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume, format, user_agent, log_messages)
#     266         try:
# --> 267             url = get_url_from_gdrive_confirmation(res.text)
#     268         except FileURLRetrievalError as e:
#
# /usr/local/lib/python3.10/dist-packages/gdown/download.py in get_url_from_gdrive_confirmation(contents)
#      54     if not url:
# ---> 55         raise FileURLRetrievalError(
#      56             "Cannot retrieve the public link of the file. "
#
# FileURLRetrievalError: Cannot retrieve the public link of the file. You may need to change the permission to 'Anyone with the link', or have had many accesses. Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# ...

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.102 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 36.5/107.7 GB disk)

# %%
# Импорты необходимых библиотек
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Загрузка предобученной модели YOLOv8
model = YOLO("yolov8n.pt")  # Можно использовать другие версии, например yolov8s.pt

# Функция для обработки изображений дефектов оконного профиля
def process_window_defects(image_path):
    # Чтение изображения
    image = cv2.imread(image_path)
    if image is None:
        print(f"Ошибка: Не удалось загрузить изображение по пути {image_path}")
        return None, None, None

    # Выполнение предсказания
    results = model.predict(image_path)

    # Список для хранения результатов
    true_positives = 0
    false_positives = 0
    false_negatives = 0

    # Обработка результатов предсказания
    for result in results:
        for box in result.boxes:
            # Получаем координаты бокса, класс объекта и уверенность
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Координаты бокса (левая верхняя и правая нижняя точки)
            class_id = int(box.cls)  # Класс объекта
            confidence = box.conf.item()  # Уверенность предсказания

            # Рисуем прямоугольник вокруг обнаруженного дефекта
            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
            label = f"Class: {model.names[class_id]}, Confidence: {confidence:.2f}"
            cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

            # Логика для подсчета TP/FP/FN
            if confidence > 0.5:  # Пример: если уверенность больше 0.5, считается TP
                true_positives += 1
            else:
                false_positives += 1

    # Ложноотрицательные (можно заменить на реальное значение, если известно общее количество дефектов)
    false_negatives = max(0, 10 - true_positives)  # Пример: всего ожидается 10 объектов

    # Отображение результата
    cv2.imshow("Detected Defects", image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    return true_positives, false_positives, false_negatives

# Функция для построения графиков точности и ошибок
def plot_metrics(tp, fp, fn):
    if tp is None or fp is None or fn is None:
        print("Ошибка: Метрики не определены.")
        return

    total_predictions = tp + fp + fn

    if total_predictions == 0:
        accuracy = 0
        error_rate = 0
    else:
        accuracy = tp / total_predictions * 100
        error_rate = (fp + fn) / total_predictions * 100

    metrics = ['True Positives', 'False Positives', 'False Negatives']
    values = [tp, fp, fn]

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.bar(metrics, values, color=['green', 'red', 'orange'])
    plt.title('Predictions Count')
    plt.ylabel('Count')

    plt.subplot(1, 2, 2)
    plt.bar(['Accuracy', 'Error Rate'], [accuracy, error_rate], color=['blue', 'purple'])
    plt.title('Model Performance')
    plt.ylabel('Percentage (%)')

    plt.tight_layout()
    plt.show()

# Путь к изображению для обработки
#image_path = "/content/drive/MyDrive/proplex_1/inclusions_all/image1.jpg"  # Укажите корректное имя изображения



# Вызов функции обработки изображений и получения метрик
true_positives, false_positives, false_negatives = process_window_defects(image_path)

# Построение графиков точности и ошибок
plot_metrics(true_positives, false_positives, false_negatives)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 87.2MB/s]
# Ошибка: Не удалось загрузить изображение по пути /content/drive/MyDrive/proplex_1/inclusions_all/image1.jpg
# Ошибка: Метрики не определены.

# %%
import os

# Путь к директории с изображениями
image_directory = "/content/drive/MyDrive/proplex_1/inclusions_all"

# Получение списка всех изображений в директории
image_files = [os.path.join(image_directory, f) for f in os.listdir(image_directory) if f.endswith(".jpg")]

# Обработка всех изображений в директории
for image_path in image_files:
    print(f"Обработка изображения: {image_path}")
    true_positives, false_positives, false_negatives = process_window_defects(image_path)
    plot_metrics(true_positives, false_positives, false_negatives)

# %%
# Импорты необходимых библиотек
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Загрузка предобученной модели YOLOv8
model = YOLO("yolov8n.pt")  # Можно использовать другие версии, например yolov8s.pt

# Функция для обработки изображений дефектов оконного профиля
def process_window_defects(image_path):
    # Чтение изображения
    image = cv2.imread(image_path)

    # Выполнение предсказания
    results = model.predict(image_path)

    # Список для хранения результатов
    true_positives = 0
    false_positives = 0
    false_negatives = 0

    # Обработка результатов
    for result in results:
        boxes = result.boxes  # Получаем предсказанные боксы
        for box in boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Координаты бокса
            class_id = int(box.cls)  # Класс объекта
            confidence = box.conf  # Уверенность предсказания

            # Рисуем прямоугольник вокруг обнаруженного дефекта
            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
            label = f"Class: {model.names[class_id]}, Confidence: {confidence:.2f}"
            cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

            # Здесь можно добавить логику для подсчета TP/FP/FN
            if confidence > 0.5:  # Пример: если уверенность больше 0.5, считается TP
                true_positives += 1
            else:
                false_positives += 1

    # Для демонстрации добавим фиксированное значение для ложноотрицательных (можно заменить на реальное)
    false_negatives = max(0, 10 - true_positives)  # Пример: всего ожидается 10 объектов

    # Отображение результата
    cv2.imshow("Detected Defects", image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    return true_positives, false_positives, false_negatives

# Функция для построения графиков точности и ошибок
def plot_metrics(tp, fp, fn):
    total_predictions = tp + fp + fn

    if total_predictions == 0:
        accuracy = 0
        error_rate = 0
    else:
        accuracy = tp / total_predictions * 100
        error_rate = (fp + fn) / total_predictions * 100

    metrics = ['True Positives', 'False Positives', 'False Negatives']
    values = [tp, fp, fn]

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.bar(metrics, values, color=['green', 'red', 'orange'])
    plt.title('Predictions Count')
    plt.ylabel('Count')

    plt.subplot(1, 2, 2)
    plt.bar(['Accuracy', 'Error Rate'], [accuracy, error_rate], color=['blue', 'purple'])
    plt.title('Model Performance')
    plt.ylabel('Percentage (%)')

    plt.tight_layout()
    plt.show()

# Путь к изображению для обработки
image_path = "path/to/your/window_defect_image.jpg"  # Замените на путь к вашему изображению

# Вызов функции обработки изображений и получения метрик
true_positives, false_positives, false_negatives = process_window_defects(image_path)

# Построение графиков точности и ошибок
plot_metrics(true_positives, false_positives, false_negatives)
